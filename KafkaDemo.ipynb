# %% [markdown]
# # Kafka Demo
#
# ### Connect to Kafka Broker Server
# ```
# ssh -L <local_port>:localhost:<remote_port> <user>@<remote_server> -NTf
# ```
# Find how to connect to Kafka server on Canvas lab 2 assignment page.
#
# ### To kill connection
# ```
# lsof -ti:8080 | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```

# %%
import os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-a' # x could be b, c, d, e, f

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Replace '...' with the address of your Kafka bootstrap server
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                        value_serializer=lambda x: dumps(x).encode('utf-8'))

# [TODO]: Add cities of your choice
cities = ['Hyderabad','Mumbai']

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic=topic, value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2025-01-24 10:04:22,Mumbai,26ºC
# Writing: 2025-01-24 10:04:23,Mumbai,32ºC
# Writing: 2025-01-24 10:04:24,Mumbai,28ºC
# Writing: 2025-01-24 10:04:25,Hyderabad,22ºC
# Writing: 2025-01-24 10:04:26,Hyderabad,30ºC
# Writing: 2025-01-24 10:04:27,Hyderabad,21ºC
# Writing: 2025-01-24 10:04:28,Mumbai,24ºC
# Writing: 2025-01-24 10:04:29,Hyderabad,21ºC
# Writing: 2025-01-24 10:04:30,Mumbai,20ºC
# Writing: 2025-01-24 10:04:31,Mumbai,19ºC

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Complete the missing ... parameters/arguments using the Kafka documentation
consumer = KafkaConsumer(
    'recitation-a',
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='earliest', #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:
    message = message.value.decode()
    # Default message.value type is bytes!
    print(loads(message))
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2025-01-23 16:35:04,New York City,30ºC
# 2025-01-23 16:35:06,Chicago,28ºC
# 2025-01-23 16:35:07,New York City,24ºC
# 2025-01-23 16:35:08,Shanghai,28ºC
# 2025-01-23 16:35:09,Beijing,27ºC
# 2025-01-23 16:35:10,Seoul,30ºC
# 2025-01-23 16:35:11,Chicago,22ºC
# 2025-01-23 16:35:12,New York City,28ºC
# 2025-01-23 16:35:13,New York City,30ºC
# 2025-01-23 16:35:14,Seoul,23ºC
# 2025-01-23 16:46:04,Pittsburgh,21ºC
# 2025-01-23 16:46:05,Seoul,18ºC
# 2025-01-23 16:46:06,Pittsburgh,20ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#       5 consumer = KafkaConsumer(
#       6     'recitation-a',
#       7     bootstrap_servers=['localhost:9092'],
#    (...)
#      12     auto_commit_interval_ms=1000
#      13 )
#      15 print('Reading Kafka Broker')
# ---> 16 for message in consumer:
#      17     message = message.value.decode()
#      18     # Default message.value type is bytes!
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/consumer/group.py:1203, in KafkaConsumer.__next__(self)
#    1201     return self.next_v1()
#    1202 else:
# -> 1203     return self.next_v2()
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/consumer/group.py:1211, in KafkaConsumer.next_v2(self)
#    1209     self._iterator = self._message_generator_v2()
#    1210 try:
# -> 1211     return next(self._iterator)
#    1212 except StopIteration:
#    1213     self._iterator = None
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/consumer/group.py:1126, in KafkaConsumer._message_generator_v2(self)
#    1124 def _message_generator_v2(self):
#    1125     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1126     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1127     for tp, records in record_map.items():
#    1128         # Generators are stateful, and it is possible that the tp / records
#    1129         # here may become stale during iteration -- i.e., we seek to a
#    1130         # different offset, pause consumption, or lose assignment.
#    1131         for record in records:
#    1132             # is_fetchable(tp) should handle assignment changes and offset
#    1133             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1134             # outer function destroying the existing iterator/generator
#    1135             # via self._iterator = None
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/consumer/group.py:663, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     661 remaining = timeout_ms
#     662 while not self._closed:
# --> 663     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     664     if records:
#     665         return records
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/consumer/group.py:712, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     709     self._client.poll(timeout_ms=0)
#     711 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 712 self._client.poll(timeout_ms=timeout_ms)
#     713 # after the long poll, we should check whether the group needs to rebalance
#     714 # prior to returning data so that the group can stabilize faster
#     715 if self._coordinator.need_rejoin():
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/client_async.py:601, in KafkaClient.poll(self, timeout_ms, future)
#     598             timeout = min(timeout, self.config['retry_backoff_ms'])
#     599         timeout = max(0, timeout)  # avoid negative timeouts
# --> 601     self._poll(timeout / 1000)
#     603 # called without the lock to avoid deadlock potential
#     604 # if handlers need to acquire locks
#     605 responses.extend(self._fire_pending_completed_requests())
#
# File ~/Course Work/AIEng/labs/mlip-kafka-lab/myenv/lib/python3.12/site-packages/kafka/client_async.py:633, in KafkaClient._poll(self, timeout)
#     630 self._register_send_sockets()
#     632 start_select = time.time()
# --> 633 ready = self._selector.select(timeout)
#     634 end_select = time.time()
#     635 if self._sensors:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset
